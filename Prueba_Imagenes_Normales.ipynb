# %%
import os
import time
import torch  # type: ignore
import torch.nn as nn  # type: ignore
import torch.optim as optim  # type: ignore
from torchvision import models, transforms  # type: ignore
from torch.utils.data import DataLoader, Dataset  # type: ignore
from PIL import Image
from sklearn.model_selection import KFold
import numpy as np
from torchvision.models import ResNet50_Weights  # type: ignore

# %%
import torch

# Liberar memoria caché de PyTorch
torch.cuda.empty_cache()

# Reiniciar memoria asignada
if torch.cuda.is_available():
    torch.cuda.reset_peak_memory_stats()
    
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

# %%
Image.MAX_IMAGE_PIXELS = None  # Deshabilitar el límite

# Configuración inicial
ROOT_DIR = r"C:\Users\Juanja Malo\Desktop\Deteccion-Ceramicas\Ruido"  # Ruta a la carpeta raíz con subcarpetas de etiquetas
BATCH_SIZE = 16
NUM_EPOCHS = 15
LEARNING_RATE = 0.002
IMAGE_SIZE = (512, 512)  # Tamaño deseado para las imágenes
NUM_CLASSES = len(os.listdir(ROOT_DIR))  # Número de clases (subcarpetas)
NUM_FOLDS = 5  # Número de folds para validación cruzada
MODEL_SAVE_PATH = "mejor_modelo.pth"  # Ruta para guardar el mejor modelo
SAVE_INTERVAL = 100  # Guardar checkpoint cada 100 batches
#NUM_WORKERS = os.cpu_count()  # Número de workers para cargar datos en paralelo
#print(f"Usando {NUM_WORKERS} workers para cargar datos.")
#torch.set_num_threads(16)

# Transformaciones para las imágenes
transform = transforms.Compose([
    transforms.Grayscale(num_output_channels=3),  # Convertir a RGB para compatibilidad con modelos preentrenados
    transforms.Resize(IMAGE_SIZE),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
])

# Dataset personalizado
class CustomImageDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.classes = sorted(os.listdir(root_dir))
        self.class_to_idx = {cls: idx for idx, cls in enumerate(self.classes)}
        self.image_paths = []
        self.labels = []
        for cls in self.classes:
            cls_dir = os.path.join(root_dir, cls)
            if os.path.isdir(cls_dir):
                for img_name in os.listdir(cls_dir):
                    self.image_paths.append(os.path.join(cls_dir, img_name))
                    self.labels.append(self.class_to_idx[cls])
                    
    def __len__(self):
        return len(self.image_paths)
    
    def __getitem__(self, idx):
        img_path = self.image_paths[idx]
        # Cargar imagen en RGB directamente
        image = Image.open(img_path).convert("RGB")
        label = self.labels[idx]
        if self.transform:
            image = self.transform(image)
        return image, label

# Crear dataset completo
full_dataset = CustomImageDataset(root_dir=ROOT_DIR, transform=transform)

# Dividir el dataset usando KFold
kf = KFold(n_splits=NUM_FOLDS, shuffle=True, random_state=42)

# Lista para almacenar accuracies de cada fold
accuracies = []
best_accuracy = 0.0  # Para rastrear el mejor accuracy

print(f"Tamaño del dataset completo: {len(full_dataset)} imágenes")
print(f"Clases encontradas: {full_dataset.classes}")
# Out:
# Tamaño del dataset completo: 43932 imágenes
# Clases encontradas: ['ALABAMA', 'ALMA', 'ALTAR', 'ALTEZZA', 'AMALFI', 'AMALTA', 'AMAZONIA', 'AMELIE', 'ANDROMEDA', 'ANTARES', 'AQUARIUM', 'ARGEL', 'ARIZONA', 'ARRECIFE', 'ARTICO', 'ASTI', 'ATHENAS', 'BALI', 'BASALTINA', 'BASALTO', 'BASIC', 'BELEK', 'BLACKSTONE', 'BLOSSOM', 'BOLONIA', 'BOREAL', 'BOSTON', 'BRESCIA', 'BROOKLYN', 'CALIFORNIA', 'CALIZA', 'CARRARA', 'CATANIA', 'CEMENTO', 'CEMENTO DECORADO', 'CEOL', 'CEPPO', 'CHARLOTE', 'CHLOE', 'CIPRES', 'CLOUDY_FOREST', 'CONCEPT', 'CONCRET', 'CONCRETO', 'CONTEMPO', 'CORAL', 'COTTO', 'CRETA', 'DAKAR', 'DAKARI', 'DAKOTA', 'DANAE', 'DESERT', 'DOLOMITE', 'DORNE', 'ECOSTONE', 'EMPERADOR', 'ESPACATOS', 'FACTORY', 'FENIX', 'FERRAN', 'FLOREANA', 'FLORENCIA', 'FLORENTINO', 'FLORIAN', 'FORESTA', 'FORMATO', 'FRANCINE', 'FUSION', 'GALENO', 'GALIA', 'GRANITY', 'GRECO', 'GRETA', 'GUAYACAN', 'HELI', 'HERMES', 'HYDRA', 'IBIZA', 'IPANEMA', 'ISABELA', 'IVORY', 'KAMANI', 'KANSAS', 'KAPUR', 'KYOTO_DREAM', 'LAJA', 'LEBLON', 'LIMESTONE', 'LINEN', 'LINO', 'LITIO', 'MADISON', 'MAJESTIC_BLUE', 'MALIBU', 'MANHATAN', 'MAUI', 'METAL', 'METALICOS', 'MIAMI', 'MONET', 'MONTANA', 'MORMONT', 'MURANO', 'NANTES', 'NARVI', 'NATURA', 'NATURAL', 'NATURE', 'NAVONA', 'NEBRASKA', 'NEO', 'OAKLAND', 'OKLAHOMA', 'OLIMPIA', 'OLIMPO', 'ONICE', 'OREGON', 'ORWELL', 'PADUA', 'PALIO', 'PALMIRA', 'PAMPLONA', 'PANDORA', 'PARQUET', 'PEBBLE', 'PERIGATAN', 'PLASTER', 'PLATINUM', 'POMPEYA', 'PRADO', 'QUARESTONE', 'QUEBEC', 'REFLECTION', 'RIVENDEL', 'ROCKY', 'ROMA', 'ROMA DECO', 'SANDSTONE', 'SANT', 'SANTA CLARA', 'SECOYA', 'SIENA', 'SIERRA', 'SILVERADO', 'SLATEWORK', 'SOFT_SABANA', 'SOTILE', 'STATUARIO', 'STELAR', 'STONE PRO', 'TDF', 'TERSO', 'TIRRENO', 'TORINO', 'TOULOUSE', 'TRAVERTINE', 'TRITON', 'TROPICAL_LINEN', 'TUNDRA', 'TURIN', 'URBA', 'URBAN_JUNGLE', 'UTAH', 'UYUNI', 'VENECIA', 'VENETTO', 'VESTRUM', 'WOODLAND', 'ZINERVA']

# %%
# Validación cruzada con KFold
for fold, (train_idx, test_idx) in enumerate(kf.split(full_dataset)):
    print(f"\nIniciando Fold {fold + 1}/{NUM_FOLDS}")
    fold_start_time = time.time()  # Inicia el timer del fold
    print(f"  Train indices: {len(train_idx)} imágenes")
    print(f"  Test indices: {len(test_idx)} imágenes")

    # Subconjuntos de entrenamiento y prueba con DataLoader que usan NUM_WORKERS
    train_subsampler = torch.utils.data.SubsetRandomSampler(train_idx)
    test_subsampler = torch.utils.data.SubsetRandomSampler(test_idx)
    train_loader = DataLoader(full_dataset, batch_size=BATCH_SIZE, sampler=train_subsampler)
    test_loader = DataLoader(full_dataset, batch_size=BATCH_SIZE, sampler=test_subsampler)
    
    # Inicializar el modelo preentrenado (ResNet50 como ejemplo)
    model = models.resnet50(weights=models.ResNet50_Weights.IMAGENET1K_V1)
    model.conv1 = nn.Conv2d(3, 64, kernel_size=7, stride=2, padding=3, bias=False)
    num_ftrs = model.fc.in_features
    model.fc = nn.Linear(num_ftrs, NUM_CLASSES)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"Usando dispositivo: {device}")
    model = model.to(device)
    print(next(model.parameters()).device)  # Verifica si el modelo está en la GPU


    # Definir función de pérdida y optimizador
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)

    # Ruta del checkpoint para este fold
    checkpoint_path = f"checkpoint_fold{fold+1}_latest.pth"
    start_epoch = 0  # Época a partir de la cual se reanuda
    start_batch = 0  # Batch desde el cual continuar en la época de reanudación

    # Si existe un checkpoint, cargar estado
    if os.path.exists(checkpoint_path):
        checkpoint = torch.load(checkpoint_path)
        model.load_state_dict(checkpoint['model_state_dict'])
        optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
        start_epoch = checkpoint['epoch']
        start_batch = checkpoint.get('batch_index', 0)
        print(f"Reanudando fold {fold+1} desde epoch {start_epoch+1} y batch {start_batch+1}")

    print("Por iniciar el entrenamiento")

    # Entrenamiento del modelo
    for epoch in range(start_epoch, NUM_EPOCHS):
        epoch_start_time = time.time()  # Inicia timer de la época

        model.train()
        running_loss = 0.0
        correct = 0
        total = 0
        print(f"Entrenando en {epoch+1}")
        for batch_index, (images, labels) in enumerate(train_loader):
            # Si se reanuda y estamos en la misma epoch, saltar batches ya procesados
            if epoch == start_epoch and batch_index < start_batch:
                print(f"Saltando batch {batch_index + 1} de la epoch {epoch + 1}")
                continue

            print("Batch index:", batch_index)  # Verifica el índice del batch

            images, labels = images.to(device), labels.to(device)
            print(images.device)  # Verifica si las imágenes están en la GPU
            outputs = model(images)
            loss = criterion(outputs, labels)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            _, predicted = outputs.max(1)
            total += labels.size(0)
            correct += predicted.eq(labels).sum().item()

            # Guardar checkpoint periódicamente
            if (batch_index + 1) % SAVE_INTERVAL == 0:
                torch.save({
                    'epoch': epoch,
                    'batch_index': batch_index + 1,
                    'model_state_dict': model.state_dict(),
                    'optimizer_state_dict': optimizer.state_dict(),
                    'loss': loss.item()
                }, checkpoint_path)
                print(f"Checkpoint guardado: {checkpoint_path} (Epoch {epoch+1}, Batch {batch_index+1})")

        # Guardar checkpoint al final de la época
        torch.save({
            'epoch': epoch + 1,  # Se incrementa para indicar que la epoch terminó
            'batch_index': 0,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'loss': running_loss / len(train_loader)
        }, checkpoint_path)
        print(f"Checkpoint final de la epoch guardado: {checkpoint_path}")

        epoch_loss = running_loss / len(train_loader)
        epoch_accuracy = 100.0 * correct / total
        epoch_end_time = time.time()  # Fin del timer de la época
        epoch_duration = epoch_end_time - epoch_start_time
        print(f"Epoch [{epoch+1}/{NUM_EPOCHS}], Loss: {epoch_loss:.4f}, Accuracy: {epoch_accuracy:.2f}%, Tiempo: {epoch_duration:.2f} segundos")
        
        # Reiniciar start_batch para las epochs siguientes
        start_batch = 0

    # Evaluación del modelo en el conjunto de prueba
    model.eval()
    test_correct = 0
    test_total = 0
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            _, predicted = outputs.max(1)
            test_total += labels.size(0)
            test_correct += predicted.eq(labels).sum().item()

    test_accuracy = 100.0 * test_correct / test_total
    print(f"Fold {fold + 1} Test Accuracy: {test_accuracy:.2f}%")
    accuracies.append(test_accuracy)

    # Guardar el mejor modelo global si se mejora la accuracy
    if test_accuracy > best_accuracy:
        best_accuracy = test_accuracy
        torch.save(model.state_dict(), MODEL_SAVE_PATH)
        print(f"Nuevo mejor modelo guardado con accuracy: {best_accuracy:.2f}%")

    # (Opcional) Eliminar el checkpoint del fold si ya no es necesario
    if os.path.exists(checkpoint_path):
        os.remove(checkpoint_path)

    fold_end_time = time.time()  # Fin del timer del fold
    fold_duration = fold_end_time - fold_start_time
    print(f"Tiempo total para Fold {fold + 1}: {fold_duration:.2f} segundos")

final_accuracy = np.mean(accuracies)
print(f"\nFinal Average Test Accuracy: {final_accuracy:.2f}%")
# Out:
# Iniciando Fold 1/5
#   Train indices: 35145 imágenes
#   Test indices: 8787 imágenes
# Usando dispositivo: cuda
# cuda:0
# Por iniciar el entrenamiento
# Entrenando en 1
# Batch index: 0
# cuda:0
# Batch index: 1
# cuda:0
# Batch index: 2
# cuda:0
# Batch index: 3
# cuda:0
# Batch index: 4
# cuda:0
# Batch index: 5
# cuda:0
# Batch index: 6
# cuda:0
# Batch index: 7
# cuda:0
# Batch index: 8
# cuda:0
# Batch index: 9
# cuda:0
# Batch index: 10
# cuda:0
# Batch index: 11
# cuda:0
# Batch index: 12
# cuda:0
# Batch index: 13
# cuda:0
# Batch index: 14
# cuda:0
# Batch index: 15
# cuda:0
# Batch index: 16
# cuda:0
# Batch index: 17
# cuda:0
# Batch index: 18
# cuda:0
# Batch index: 19
# cuda:0
# Batch index: 20
# cuda:0
# Batch index: 21
# cuda:0
# Batch index: 22
# cuda:0
# Batch index: 23
# cuda:0
# Batch index: 24
# cuda:0
# Batch index: 25
# cuda:0
# Batch index: 26
# cuda:0
# Batch index: 27
# cuda:0
# Batch index: 28
# cuda:0
# Batch index: 29
# cuda:0
# Batch index: 30
# cuda:0
# Batch index: 31
# cuda:0
# Batch index: 32
# cuda:0
# Batch index: 33
# cuda:0
# Batch index: 34
# cuda:0
# Batch index: 35
# cuda:0
# Batch index: 36
# cuda:0
# Batch index: 37
# cuda:0
# Batch index: 38
# cuda:0
# Batch index: 39
# cuda:0
# Batch index: 40
# cuda:0
# Batch index: 41
# cuda:0
# Batch index: 42
# cuda:0
# Batch index: 43
# cuda:0
# Batch index: 44
# cuda:0
# Batch index: 45
# cuda:0
# Batch index: 46
# cuda:0
# Batch index: 47
# cuda:0
# Batch index: 48
# cuda:0
# Batch index: 49
# cuda:0
# Batch index: 50
# cuda:0
# Batch index: 51
# cuda:0
# Batch index: 52
# cuda:0
# Batch index: 53
# cuda:0
# Batch index: 54
# cuda:0
# Batch index: 55
# cuda:0
# Batch index: 56
# cuda:0
# Batch index: 57
# cuda:0
# Batch index: 58
# cuda:0
# Batch index: 59
# cuda:0
# Batch index: 60
# cuda:0
# Batch index: 61
# cuda:0
# Batch index: 62
# cuda:0
# Batch index: 63
# cuda:0
# Batch index: 64
# cuda:0
# Batch index: 65
# cuda:0
# Batch index: 66
# cuda:0
# Batch index: 67
# cuda:0
# Batch index: 68
# cuda:0
# Batch index: 69
# cuda:0
# Batch index: 70
# cuda:0
# Batch index: 71
# cuda:0
# Batch index: 72
# cuda:0
# Batch index: 73
# cuda:0
# Batch index: 74
# cuda:0
# Batch index: 75
# cuda:0
# Batch index: 76
# cuda:0
# Batch index: 77
# cuda:0
# Batch index: 78
# cuda:0
# Batch index: 79
# cuda:0
# Batch index: 80
# cuda:0
# Batch index: 81
# cuda:0
# Batch index: 82
# cuda:0
# Batch index: 83
# cuda:0
# Batch index: 84
# cuda:0
# Batch index: 85
# cuda:0
# Batch index: 86
# cuda:0
# Batch index: 87
# cuda:0
# Batch index: 88
# cuda:0
# Batch index: 89
# cuda:0
# Batch index: 90
# cuda:0
# Batch index: 91
# cuda:0
# Batch index: 92
# cuda:0
# Batch index: 93
# cuda:0
# Batch index: 94
# cuda:0
# Batch index: 95
# cuda:0
# Batch index: 96
# cuda:0
# Batch index: 97
# cuda:0
# Batch index: 98
# cuda:0
# Batch index: 99
# cuda:0
# Checkpoint guardado: checkpoint_fold1_latest.pth (Epoch 1, Batch 100)
# Batch index: 100
# cuda:0
# Batch index: 101
# cuda:0
# Batch index: 102
# cuda:0
# Batch index: 103
# cuda:0
# Batch index: 104
# cuda:0
# Batch index: 105
# cuda:0
# Batch index: 106
# cuda:0
# Batch index: 107
# cuda:0
# Batch index: 108
# cuda:0
# Batch index: 109
# cuda:0
# Batch index: 110
# cuda:0
# Batch index: 111
# cuda:0
# Batch index: 112
# cuda:0
# Batch index: 113
# cuda:0
# Batch index: 114
# cuda:0
# Batch index: 115
# cuda:0
# Batch index: 116
# cuda:0
# Batch index: 117
# cuda:0
# Batch index: 118
# cuda:0
# Batch index: 119
# cuda:0
# Batch index: 120
# cuda:0
# Batch index: 121
# cuda:0
# Batch index: 122
# cuda:0
# Batch index: 123
# cuda:0
# Batch index: 124
# cuda:0
# Batch index: 125
# cuda:0
# Batch index: 126
# cuda:0
# Batch index: 127
# cuda:0
# Batch index: 128
# cuda:0
# Batch index: 129
# cuda:0
# Batch index: 130
# cuda:0
# Batch index: 131
# cuda:0
# Batch index: 132
# cuda:0
# Batch index: 133
# cuda:0
# Batch index: 134
# cuda:0
# Batch index: 135
# cuda:0
# Batch index: 136
# cuda:0
# Batch index: 137
# cuda:0
# Batch index: 138
# cuda:0
# Batch index: 139
# cuda:0
# Batch index: 140
# cuda:0
# Batch index: 141
# cuda:0
# Batch index: 142
# cuda:0
# Batch index: 143
# cuda:0
# Batch index: 144
# cuda:0
# Batch index: 145
# cuda:0
# Batch index: 146
# cuda:0
# Batch index: 147
# cuda:0
# Batch index: 148
# cuda:0
# Batch index: 149
# cuda:0
# Batch index: 150
# cuda:0
# Batch index: 151
# cuda:0
# Batch index: 152
# cuda:0
# Batch index: 153
# cuda:0
# Batch index: 154
# cuda:0
# Batch index: 155
# cuda:0
# Batch index: 156
# cuda:0
# Batch index: 157
# cuda:0
# Batch index: 158
# cuda:0
# Batch index: 159
# cuda:0
# Batch index: 160
# cuda:0
# Batch index: 161
# cuda:0
# Batch index: 162
# cuda:0
# Batch index: 163
# cuda:0
# Batch index: 164
# cuda:0
# Batch index: 165
# cuda:0
# Batch index: 166
# cuda:0
# Batch index: 167
# cuda:0
# Batch index: 168
# cuda:0
# Batch index: 169
# cuda:0
# Batch index: 170
# cuda:0
# Batch index: 171
# cuda:0
# Batch index: 172
# cuda:0
# Batch index: 173
# cuda:0
# Batch index: 174
# cuda:0
# Batch index: 175
# cuda:0
# Batch index: 176
# cuda:0
# Batch index: 177
# cuda:0
# Batch index: 178
# cuda:0
# Batch index: 179
# cuda:0
# Batch index: 180
# cuda:0
# Batch index: 181
# cuda:0
# Batch index: 182
# cuda:0
# Batch index: 183
# cuda:0
# Batch index: 184
# cuda:0
# Batch index: 185
# cuda:0
# Batch index: 186
# cuda:0
# Batch index: 187
# cuda:0
# Batch index: 188
# cuda:0
# Batch index: 189
# cuda:0
# Batch index: 190
# cuda:0
# Batch index: 191
# cuda:0
# Batch index: 192
# cuda:0
# Batch index: 193
# cuda:0
# Batch index: 194
# cuda:0
# Batch index: 195
# cuda:0
# Batch index: 196
# cuda:0
# Batch index: 197
# cuda:0
# Batch index: 198
# cuda:0
# Batch index: 199
# cuda:0
# Checkpoint guardado: checkpoint_fold1_latest.pth (Epoch 1, Batch 200)
# Batch index: 200
# cuda:0
# Batch index: 201
# cuda:0
# Batch index: 202
# cuda:0
# Batch index: 203
# cuda:0
# Batch index: 204
# cuda:0
# Batch index: 205
# cuda:0
# Batch index: 206
# cuda:0
# Batch index: 207
# cuda:0
# Batch index: 208
# cuda:0
# Batch index: 209
# cuda:0
# Batch index: 210
# cuda:0
# Batch index: 211
# cuda:0
# Batch index: 212
# cuda:0
# Batch index: 213
# cuda:0
# Batch index: 214
# cuda:0
# Batch index: 215
# cuda:0
# Batch index: 216
# cuda:0
# Batch index: 217
# cuda:0
# Batch index: 218
# cuda:0
# Batch index: 219
# cuda:0
# Batch index: 220
# cuda:0
# Batch index: 221
# cuda:0
# Batch index: 222
# cuda:0
# Batch index: 223
# cuda:0
# Batch index: 224
# cuda:0
# Batch index: 225
# cuda:0
# Batch index: 226
# cuda:0
# Batch index: 227
# cuda:0
# Batch index: 228
# cuda:0
# Batch index: 229
# cuda:0
# Batch index: 230
# cuda:0
# Batch index: 231
# cuda:0
# Batch index: 232
# cuda:0
# Batch index: 233
# cuda:0
# Batch index: 234
# cuda:0
# Batch index: 235
# cuda:0
# Batch index: 236
# cuda:0
# Batch index: 237
# cuda:0
# Batch index: 238
# cuda:0
# Batch index: 239
# cuda:0
# Batch index: 240
# cuda:0
# Batch index: 241
# cuda:0
# Batch index: 242
# cuda:0
# Batch index: 243
# cuda:0
# Batch index: 244
# cuda:0
# Batch index: 245
# cuda:0
# Batch index: 246
# cuda:0
# Batch index: 247
# cuda:0
# Batch index: 248
# cuda:0
# Batch index: 249
# cuda:0
# Batch index: 250
# cuda:0
# Batch index: 251
# cuda:0
# Batch index: 252
# cuda:0
# Batch index: 253
# cuda:0
# Batch index: 254
# cuda:0
# Batch index: 255
# cuda:0
# Batch index: 256
# cuda:0
# Batch index: 257
# cuda:0
# Batch index: 258
# cuda:0
# Batch index: 259
# cuda:0
# Batch index: 260
# cuda:0
# Batch index: 261
# cuda:0
# Batch index: 262
# cuda:0
# Batch index: 263
# cuda:0
# Batch index: 264
# cuda:0
# Batch index: 265
# cuda:0
# Batch index: 266
# cuda:0
# Batch index: 267
# cuda:0
# Batch index: 268
# cuda:0
# Batch index: 269
# cuda:0
# Batch index: 270
# cuda:0
# Batch index: 271
# cuda:0
# Batch index: 272
# cuda:0
# Batch index: 273
# cuda:0
# Batch index: 274
# cuda:0
# Batch index: 275
# cuda:0
# Batch index: 276
# cuda:0
# Batch index: 277
# cuda:0
# Batch index: 278
# cuda:0
# Batch index: 279
# cuda:0
# Batch index: 280
# cuda:0
# Batch index: 281
# cuda:0
# Batch index: 282
# cuda:0
# Batch index: 283
# cuda:0
# Batch index: 284
# cuda:0
# Batch index: 285
# cuda:0
# Batch index: 286
# cuda:0
# Batch index: 287
# cuda:0
# Batch index: 288
# cuda:0
# Batch index: 289
# cuda:0
# Batch index: 290
# cuda:0
# Batch index: 291
# cuda:0
# Batch index: 292
# cuda:0
# Batch index: 293
# cuda:0
# Batch index: 294
# cuda:0
# Batch index: 295
# cuda:0
# Batch index: 296
# cuda:0
# Batch index: 297
# cuda:0
# Batch index: 298
# cuda:0
# Batch index: 299
# cuda:0
# Checkpoint guardado: checkpoint_fold1_latest.pth (Epoch 1, Batch 300)
# Batch index: 300
# cuda:0
# Batch index: 301
# cuda:0
# Batch index: 302
# cuda:0
# Batch index: 303
# cuda:0
# Batch index: 304
# cuda:0
# Batch index: 305
# cuda:0
# Batch index: 306
# cuda:0
# Batch index: 307
# cuda:0
# Batch index: 308
# cuda:0
# Batch index: 309
# cuda:0
# Batch index: 310
# cuda:0
# Batch index: 311
# cuda:0
# Batch index: 312
# cuda:0
# Batch index: 313
# cuda:0
# Batch index: 314
# cuda:0
# Batch index: 315
# cuda:0
# Batch index: 316
# cuda:0
# Batch index: 317
# cuda:0
# Batch index: 318
# cuda:0
# Batch index: 319
# cuda:0
# Batch index: 320
# cuda:0
# Batch index: 321
# cuda:0
# Batch index: 322
# cuda:0
# Batch index: 323
# cuda:0
# Batch index: 324
# cuda:0
# Batch index: 325
# cuda:0
# Batch index: 326
# cuda:0
# Batch index: 327
# cuda:0
# Batch index: 328
# cuda:0
# Batch index: 329
# cuda:0
# Batch index: 330
# cuda:0
# Batch index: 331
# cuda:0
# Batch index: 332
# cuda:0
# Batch index: 333
# cuda:0
# Batch index: 334
# cuda:0
# Batch index: 335
# cuda:0
# Batch index: 336
# cuda:0
# Batch index: 337
# cuda:0
# Batch index: 338
# cuda:0
# Batch index: 339
# cuda:0
# Batch index: 340
# cuda:0
# Batch index: 341
# cuda:0
# Batch index: 342
# cuda:0
# Batch index: 343
# cuda:0
# Batch index: 344
# cuda:0
# Batch index: 345
# cuda:0
# Batch index: 346
# cuda:0
# Batch index: 347
# cuda:0
# Batch index: 348
# cuda:0
# Batch index: 349
# cuda:0
# Batch index: 350
# cuda:0
# Batch index: 351
# cuda:0
# Batch index: 352
# cuda:0
# Batch index: 353
# cuda:0
# Batch index: 354
# cuda:0
# Batch index: 355
# cuda:0
# Batch index: 356
# cuda:0
# Batch index: 357
# cuda:0
# Batch index: 358
# cuda:0
# Batch index: 359
# cuda:0
# Batch index: 360
# cuda:0
# Batch index: 361
# cuda:0
# Batch index: 362
# cuda:0
# Batch index: 363
# cuda:0
# Batch index: 364
# cuda:0
# Batch index: 365
# cuda:0
# Batch index: 366
# cuda:0
# Batch index: 367
# cuda:0
# Batch index: 368
# cuda:0
# Batch index: 369
# cuda:0
# Batch index: 370
# cuda:0
# Batch index: 371
# cuda:0
# Batch index: 372
# cuda:0
# Batch index: 373
# cuda:0
# Batch index: 374
# cuda:0
# Batch index: 375
# cuda:0
# Batch index: 376
# cuda:0
# Batch index: 377
# cuda:0
# Batch index: 378
# cuda:0
# Batch index: 379
# cuda:0
# Batch index: 380
# cuda:0
# Batch index: 381
# cuda:0
# Batch index: 382
# cuda:0
# Batch index: 383
# cuda:0
# Batch index: 384
# cuda:0
# Batch index: 385
# cuda:0
# Batch index: 386
# cuda:0
# Batch index: 387
# cuda:0
# Batch index: 388
# cuda:0
# Batch index: 389
# cuda:0
# Batch index: 390
# cuda:0
# Batch index: 391
# cuda:0
# Batch index: 392
# cuda:0
# Batch index: 393
# cuda:0
# Batch index: 394
# cuda:0
# Batch index: 395
# cuda:0
# Batch index: 396
# cuda:0
# Batch index: 397
# cuda:0
# Batch index: 398
# cuda:0
# Batch index: 399
# cuda:0
# Checkpoint guardado: checkpoint_fold1_latest.pth (Epoch 1, Batch 400)
# Batch index: 400
# cuda:0
# Batch index: 401
# cuda:0
# Batch index: 402
# cuda:0
# Batch index: 403
# cuda:0
# Batch index: 404
# cuda:0
# Batch index: 405
# cuda:0
# Batch index: 406
# cuda:0
# Batch index: 407
# cuda:0
# Batch index: 408
# cuda:0
# Batch index: 409
# cuda:0
# Batch index: 410
# cuda:0
# Batch index: 411
# cuda:0
# Batch index: 412
# cuda:0
# Batch index: 413
# cuda:0
# Batch index: 414
# cuda:0
# Batch index: 415
# cuda:0
# Batch index: 416
# cuda:0
# Batch index: 417
# cuda:0
# Batch index: 418
# cuda:0
# Batch index: 419
# cuda:0
# Batch index: 420
# cuda:0
# Batch index: 421
# cuda:0
# Batch index: 422
# cuda:0
# Batch index: 423
# cuda:0
# Batch index: 424
# cuda:0
# Batch index: 425
# cuda:0
# Batch index: 426
# cuda:0
# Batch index: 427
# cuda:0
# Batch index: 428
# cuda:0
# Batch index: 429
# cuda:0
# Batch index: 430
# cuda:0
# Batch index: 431
# cuda:0
# Batch index: 432
# cuda:0
# Batch index: 433
# cuda:0
# Batch index: 434
# cuda:0
# Batch index: 435
# cuda:0
# Batch index: 436
# cuda:0
# Batch index: 437
# cuda:0
# Batch index: 438
# cuda:0
# Batch index: 439
# cuda:0
# Batch index: 440
# cuda:0
# Batch index: 441
# cuda:0
# Batch index: 442
# cuda:0
# Batch index: 443
# cuda:0
# Batch index: 444
# cuda:0
# Batch index: 445
# cuda:0
# Batch index: 446
# cuda:0
# Batch index: 447
# cuda:0
# Batch index: 448
# cuda:0
# Batch index: 449
# cuda:0
# Batch index: 450
# cuda:0
# Batch index: 451
# cuda:0
# Batch index: 452
# cuda:0
# Batch index: 453
# cuda:0
# Batch index: 454
# cuda:0
# Batch index: 455
# cuda:0
# Batch index: 456
# cuda:0
# Batch index: 457
# cuda:0
# Batch index: 458
# cuda:0
# Batch index: 459
# cuda:0
# Batch index: 460
# cuda:0
# Batch index: 461
# cuda:0
# Batch index: 462
# cuda:0
# Batch index: 463
# cuda:0
# Batch index: 464
# cuda:0
# Batch index: 465
# cuda:0
# Batch index: 466
# cuda:0
# Batch index: 467
# cuda:0
# Batch index: 468
# cuda:0
# Batch index: 469
# cuda:0
# Batch index: 470
# cuda:0
# Batch index: 471
# cuda:0
# Batch index: 472
# cuda:0
# Batch index: 473
# cuda:0
# Batch index: 474
# cuda:0
# Batch index: 475
# cuda:0
# Batch index: 476
# cuda:0
# Batch index: 477
# cuda:0
# Batch index: 478
# cuda:0
# Batch index: 479
# cuda:0
# Batch index: 480
# cuda:0
# Batch index: 481
# cuda:0
# Batch index: 482
# cuda:0
# Batch index: 483
# cuda:0
# Batch index: 484
# cuda:0
# Batch index: 485
# cuda:0
# Batch index: 486
# cuda:0
# Batch index: 487
# cuda:0
# Batch index: 488
# cuda:0
# Batch index: 489
# cuda:0
# Batch index: 490
# cuda:0
# Batch index: 491
# cuda:0
# Batch index: 492
# cuda:0
# Batch index: 493
# cuda:0
# Batch index: 494
# cuda:0
# Batch index: 495
# cuda:0
# Batch index: 496
# cuda:0
# Batch index: 497
# cuda:0
# Batch index: 498
# cuda:0
# Batch index: 499
# cuda:0
# Checkpoint guardado: checkpoint_fold1_latest.pth (Epoch 1, Batch 500)
# Batch index: 500
# cuda:0
# Batch index: 501
# cuda:0
# Batch index: 502
# cuda:0
# Batch index: 503
# cuda:0
# Batch index: 504
# cuda:0
# Batch index: 505
# cuda:0
# Batch index: 506
# cuda:0
# Batch index: 507
# cuda:0
# Batch index: 508
# cuda:0
# Batch index: 509
# cuda:0
# Batch index: 510
# cuda:0
# Batch index: 511
# cuda:0
# Batch index: 512
# cuda:0
# Batch index: 513
# cuda:0
# Batch index: 514
# cuda:0
# Batch index: 515
# cuda:0
# Batch index: 516
# cuda:0
# Batch index: 517
# cuda:0
# Batch index: 518
# cuda:0
# Batch index: 519
# cuda:0
# Batch index: 520
# cuda:0
# Batch index: 521
# cuda:0
# Batch index: 522
# cuda:0
# Batch index: 523
# cuda:0
# Batch index: 524
# cuda:0
# Batch index: 525
# cuda:0
# Batch index: 526
# cuda:0
# Batch index: 527
# cuda:0
# Batch index: 528
# cuda:0
# Batch index: 529
# cuda:0
# Batch index: 530
# cuda:0
# Batch index: 531
# cuda:0
# Batch index: 532
# cuda:0
# Batch index: 533
# cuda:0
# Batch index: 534
# cuda:0
# Batch index: 535
# cuda:0
# Batch index: 536
# cuda:0
# Batch index: 537
# cuda:0
# Batch index: 538
# cuda:0
# Batch index: 539
# cuda:0
# Batch index: 540
# cuda:0
# Batch index: 541
# cuda:0
# Batch index: 542
# cuda:0
# Batch index: 543
# cuda:0
# Batch index: 544
# cuda:0
# Batch index: 545
# cuda:0
# Batch index: 546
# cuda:0
# Batch index: 547
# cuda:0
# Batch index: 548
# cuda:0
# Batch index: 549
# cuda:0
# Batch index: 550
# cuda:0
# Batch index: 551
# cuda:0
# Batch index: 552
# cuda:0
# Batch index: 553
# cuda:0
# Batch index: 554
# cuda:0
# Batch index: 555
# cuda:0
# Batch index: 556
# cuda:0
# Batch index: 557
# cuda:0
# Batch index: 558
# cuda:0
# Batch index: 559
# cuda:0
# Batch index: 560
# cuda:0
# Batch index: 561
# cuda:0
# Batch index: 562
# cuda:0
# Batch index: 563
# cuda:0
# Batch index: 564
# cuda:0
# Batch index: 565
# cuda:0
# Batch index: 566
# cuda:0
# Batch index: 567
# cuda:0
# Batch index: 568
# cuda:0
# Batch index: 569
# cuda:0
# Batch index: 570
# cuda:0
# Batch index: 571
# cuda:0
# Batch index: 572
# cuda:0
# Batch index: 573
# cuda:0
# Batch index: 574
# cuda:0
# Batch index: 575
# cuda:0
# Batch index: 576
# cuda:0
# Batch index: 577
# cuda:0
# Batch index: 578
# cuda:0
# Batch index: 579
# cuda:0
# Batch index: 580
# cuda:0
# Batch index: 581
# cuda:0
# Batch index: 582
# cuda:0
# Batch index: 583
# cuda:0
# Batch index: 584
# cuda:0
# Batch index: 585
# cuda:0
# Batch index: 586
# cuda:0
# Batch index: 587
# cuda:0
# Batch index: 588
# cuda:0
# Batch index: 589
# cuda:0
# Batch index: 590
# cuda:0
# Batch index: 591
# cuda:0
# Batch index: 592
# cuda:0
# Batch index: 593
# cuda:0
# Batch index: 594
# cuda:0
# Batch index: 595
# cuda:0
# Batch index: 596
# cuda:0
# Batch index: 597
# cuda:0
# Batch index: 598
# cuda:0
# Batch index: 599
# cuda:0
# Checkpoint guardado: checkpoint_fold1_latest.pth (Epoch 1, Batch 600)
# Batch index: 600
# cuda:0
# Batch index: 601
# cuda:0
# Batch index: 602
# cuda:0
# Batch index: 603
# cuda:0
# Batch index: 604
# cuda:0
# Batch index: 605
# cuda:0
# Batch index: 606
# cuda:0
# Batch index: 607
# cuda:0
# Batch index: 608
# cuda:0
# Batch index: 609
# cuda:0
# Batch index: 610
# cuda:0
# Batch index: 611
# cuda:0
# Batch index: 612
# cuda:0
# Batch index: 613
# cuda:0
# Batch index: 614
# cuda:0
# Batch index: 615
# cuda:0
# Batch index: 616
# cuda:0
# Batch index: 617
# cuda:0
# Batch index: 618
# cuda:0
# Batch index: 619
# cuda:0
# Batch index: 620
# cuda:0
# Batch index: 621
# cuda:0
# Batch index: 622
# cuda:0
# Batch index: 623
# cuda:0
# Batch index: 624
# cuda:0
# Batch index: 625
# cuda:0
# Batch index: 626
# cuda:0
# Batch index: 627
# cuda:0
# Batch index: 628
# cuda:0
# Batch index: 629
# cuda:0
# Batch index: 630
# cuda:0
# Batch index: 631
# cuda:0
# Batch index: 632
# cuda:0
# Batch index: 633
# cuda:0
# Batch index: 634
# cuda:0
# Batch index: 635
# cuda:0
# Batch index: 636
# cuda:0
# Batch index: 637
# cuda:0
# Batch index: 638
# cuda:0
# Batch index: 639
# cuda:0
# Batch index: 640
# cuda:0
# Batch index: 641
# cuda:0
# Batch index: 642
# cuda:0
# Batch index: 643
# cuda:0
# Batch index: 644
# cuda:0
# Batch index: 645
# cuda:0
# Batch index: 646
# cuda:0
# Batch index: 647
# cuda:0
# Batch index: 648
# cuda:0
# Batch index: 649
# cuda:0
# Batch index: 650
# cuda:0
# Batch index: 651
# cuda:0
# Batch index: 652
# cuda:0
# Batch index: 653
# cuda:0
# Batch index: 654
# cuda:0
# Batch index: 655
# cuda:0
# Batch index: 656
# cuda:0
# Batch index: 657
# cuda:0
# Batch index: 658
# cuda:0
# Batch index: 659
# cuda:0
# Batch index: 660
# cuda:0
# Batch index: 661
# cuda:0
# Batch index: 662
# cuda:0
# Batch index: 663
# cuda:0
# Batch index: 664
# cuda:0
# Batch index: 665
# cuda:0
# Batch index: 666
# cuda:0
# Batch index: 667
# cuda:0
# Batch index: 668
# cuda:0
# Batch index: 669
# cuda:0
# Batch index: 670
# cuda:0
# Batch index: 671
# cuda:0
# Batch index: 672
# cuda:0
# Batch index: 673
# cuda:0
# Batch index: 674
# cuda:0
# Batch index: 675
# cuda:0
# Batch index: 676
# cuda:0
# Batch index: 677
# cuda:0
# Batch index: 678
# cuda:0
# Batch index: 679
# cuda:0
# Batch index: 680
# cuda:0
# Batch index: 681
# cuda:0
# Batch index: 682
# cuda:0
# Batch index: 683
# cuda:0
# Batch index: 684
# cuda:0
# Batch index: 685
# cuda:0
# Batch index: 686
# cuda:0
# Batch index: 687
# cuda:0
# Batch index: 688
# cuda:0
# Batch index: 689
# cuda:0
# Batch index: 690
# cuda:0
# Batch index: 691
# cuda:0
# Batch index: 692
# cuda:0
# Batch index: 693
# cuda:0
# Batch index: 694
# cuda:0
# Batch index: 695
# cuda:0
# Batch index: 696
# cuda:0
# Batch index: 697
# cuda:0
# Batch index: 698
# cuda:0
# Batch index: 699
# cuda:0
# Checkpoint guardado: checkpoint_fold1_latest.pth (Epoch 1, Batch 700)
# Batch index: 700
# cuda:0
# Batch index: 701
# cuda:0
# Batch index: 702
# cuda:0
# Batch index: 703
# cuda:0
# Batch index: 704
# cuda:0
# Batch index: 705
# cuda:0
# Batch index: 706
# cuda:0
# Batch index: 707
# cuda:0
# Batch index: 708
# cuda:0
# Batch index: 709
# cuda:0
# Batch index: 710
# cuda:0
# Batch index: 711
# cuda:0
# Batch index: 712
# cuda:0
# Batch index: 713
# cuda:0
# Batch index: 714
# cuda:0
# Batch index: 715
# cuda:0
# Batch index: 716
# cuda:0
# Batch index: 717
# cuda:0
# Batch index: 718
# cuda:0
# Batch index: 719
# cuda:0
# Batch index: 720
# cuda:0
# Batch index: 721
# cuda:0
# Batch index: 722
# cuda:0
# Batch index: 723
# cuda:0
# Batch index: 724
# cuda:0
# Batch index: 725
# cuda:0
# Batch index: 726
# cuda:0
# Batch index: 727
# cuda:0
# Batch index: 728
# cuda:0
# Batch index: 729
# cuda:0
# Batch index: 730
# cuda:0
# Batch index: 731
# cuda:0
# Batch index: 732
# cuda:0
# Batch index: 733
# cuda:0
# Batch index: 734
# cuda:0
# Batch index: 735
# cuda:0
# Batch index: 736
# cuda:0
# Batch index: 737
# cuda:0
# Batch index: 738
# cuda:0
# Batch index: 739
# cuda:0
# Batch index: 740
# cuda:0
# Batch index: 741
# cuda:0
# Batch index: 742
# cuda:0
# Batch index: 743
# cuda:0
# Batch index: 744
# cuda:0
# Batch index: 745
# cuda:0
# Batch index: 746
# cuda:0
# Batch index: 747
# cuda:0
# Batch index: 748
# cuda:0
# Batch index: 749
# cuda:0
# Batch index: 750
# cuda:0
# Batch index: 751
# cuda:0
# Batch index: 752
# cuda:0
# Batch index: 753
# cuda:0
# Batch index: 754
# cuda:0
# Batch index: 755
# cuda:0
# Batch index: 756
# cuda:0
# Batch index: 757
# cuda:0
# Batch index: 758
# cuda:0
# Batch index: 759
# cuda:0
# Batch index: 760
# cuda:0
# Batch index: 761
# cuda:0
# Batch index: 762
# cuda:0
# Batch index: 763
# cuda:0
# Batch index: 764
# cuda:0
# Batch index: 765
# cuda:0
# Batch index: 766
# cuda:0
# Batch index: 767
# cuda:0
# Batch index: 768
# cuda:0
# Batch index: 769
# cuda:0
# Batch index: 770
# cuda:0
# Batch index: 771
# cuda:0
# Batch index: 772
# cuda:0
# Batch index: 773
# cuda:0
# Batch index: 774
# cuda:0
# Batch index: 775
# cuda:0
# Batch index: 776
# cuda:0
# Batch index: 777
# cuda:0
# Batch index: 778
# cuda:0
# Batch index: 779
# cuda:0
# Batch index: 780
# cuda:0
# Batch index: 781
# cuda:0
# Batch index: 782
# cuda:0
# Batch index: 783
# cuda:0
# Batch index: 784
# cuda:0
# Batch index: 785
# cuda:0
# Batch index: 786
# cuda:0
# Batch index: 787
# cuda:0
# Batch index: 788
# cuda:0
# Batch index: 789
# cuda:0
# Batch index: 790
# cuda:0
# Batch index: 791
# cuda:0
# Batch index: 792
# cuda:0
# Batch index: 793
# cuda:0
# Batch index: 794
# cuda:0
# Batch index: 795
# cuda:0
# Batch index: 796
# cuda:0
# Batch index: 797
# cuda:0
# Batch index: 798
# cuda:0
# Batch index: 799
# cuda:0
# Checkpoint guardado: checkpoint_fold1_latest.pth (Epoch 1, Batch 800)
# Batch index: 800
# cuda:0
# Batch index: 801
# cuda:0
# Batch index: 802
# cuda:0
# Batch index: 803
# cuda:0
# Batch index: 804
# cuda:0
# Batch index: 805
# cuda:0
# Batch index: 806
# cuda:0
# Batch index: 807
# cuda:0
# Batch index: 808
# cuda:0
# Batch index: 809
# cuda:0
# Batch index: 810
# cuda:0
# Batch index: 811
# cuda:0
# Batch index: 812
# cuda:0
# Batch index: 813
# cuda:0
# Batch index: 814
# cuda:0
# Batch index: 815
# cuda:0
# Batch index: 816
# cuda:0
# Batch index: 817
# cuda:0
# Batch index: 818
# cuda:0
# Batch index: 819
# cuda:0
# Batch index: 820
# cuda:0
# Batch index: 821
# cuda:0
# Batch index: 822
# cuda:0
# Batch index: 823
# cuda:0
# Batch index: 824
# cuda:0
# Batch index: 825
# cuda:0
# Batch index: 826
# cuda:0
# Batch index: 827
# cuda:0
# Batch index: 828
# cuda:0
# Batch index: 829
# cuda:0
# Batch index: 830
# cuda:0
# Batch index: 831
# cuda:0
# Batch index: 832
# cuda:0
# Batch index: 833
# cuda:0
# Batch index: 834
# cuda:0
# Batch index: 835
# cuda:0
# Batch index: 836
# cuda:0
# Batch index: 837
# cuda:0
# Batch index: 838
# cuda:0
# Batch index: 839
# cuda:0
# Batch index: 840
# cuda:0
# Batch index: 841
# cuda:0
# Batch index: 842
# cuda:0
# Batch index: 843
# cuda:0
# Batch index: 844
# cuda:0
# Batch index: 845
# cuda:0
# Batch index: 846
# cuda:0
# Batch index: 847
# cuda:0
# Batch index: 848
# cuda:0
# Batch index: 849
# cuda:0
# Batch index: 850
# cuda:0
# Batch index: 851
# cuda:0
# Batch index: 852
# cuda:0
# Batch index: 853
# cuda:0
# Batch index: 854
# cuda:0
# Batch index: 855
# cuda:0
# Batch index: 856
# cuda:0
# Batch index: 857
# cuda:0
# Batch index: 858
# cuda:0
# Batch index: 859
# cuda:0
# Batch index: 860
# cuda:0
# Batch index: 861
# cuda:0
# Batch index: 862
# cuda:0
# Batch index: 863
# cuda:0
# Batch index: 864
# cuda:0
# Batch index: 865
# cuda:0
# Batch index: 866
# cuda:0
# Batch index: 867
# cuda:0
# Batch index: 868
# cuda:0
# Batch index: 869
# cuda:0
# Batch index: 870
# cuda:0
# Batch index: 871
# cuda:0
# Batch index: 872
# cuda:0
# Batch index: 873
# cuda:0
# Batch index: 874
# cuda:0
# Batch index: 875
# cuda:0
# Batch index: 876
# cuda:0
# Batch index: 877
# cuda:0
# Batch index: 878
# cuda:0
# Batch index: 879
# cuda:0
# Batch index: 880
# cuda:0
# Batch index: 881
# cuda:0
# Batch index: 882
# cuda:0
# Batch index: 883
# cuda:0
# Batch index: 884
# cuda:0
# Batch index: 885
# cuda:0
# Batch index: 886
# cuda:0
# Batch index: 887
# cuda:0
# Batch index: 888
# cuda:0
# Batch index: 889
# cuda:0
# Batch index: 890
# cuda:0
# Batch index: 891
# cuda:0
# Batch index: 892
# cuda:0
# Batch index: 893
# cuda:0
# Batch index: 894
# cuda:0
# Batch index: 895
# cuda:0
# Batch index: 896
# cuda:0
# Batch index: 897
# cuda:0
# Batch index: 898
# cuda:0
# Batch index: 899
# cuda:0
# Checkpoint guardado: checkpoint_fold1_latest.pth (Epoch 1, Batch 900)
# Batch index: 900
# cuda:0
# Batch index: 901
# cuda:0
# Batch index: 902
# cuda:0
# Batch index: 903
# cuda:0
# Batch index: 904
# cuda:0
# Batch index: 905
# cuda:0
# Batch index: 906
# cuda:0
# Batch index: 907
# cuda:0
# Batch index: 908
# cuda:0
# Batch index: 909
# cuda:0
# Batch index: 910
# cuda:0
# Batch index: 911
# cuda:0
# Batch index: 912
# cuda:0
# Batch index: 913
# cuda:0
# Batch index: 914
# cuda:0
# Batch index: 915
# cuda:0
# Batch index: 916
# cuda:0
# Batch index: 917
# cuda:0
# Batch index: 918
# cuda:0
# Batch index: 919
# cuda:0
# Batch index: 920
# cuda:0
# Batch index: 921
# cuda:0
# Batch index: 922
# cuda:0
# Batch index: 923
# cuda:0
# Batch index: 924
# cuda:0
# Batch index: 925
# cuda:0
# Batch index: 926
# cuda:0
# Batch index: 927
# cuda:0
# Batch index: 928
# cuda:0
# Batch index: 929
# cuda:0
# Batch index: 930
# cuda:0
# Batch index: 931
# cuda:0
# Batch index: 932
# cuda:0
# Batch index: 933
# cuda:0
# Batch index: 934
# cuda:0
# Batch index: 935
# cuda:0
# Batch index: 936
# cuda:0
# Batch index: 937
# cuda:0
# Batch index: 938
# cuda:0
# Batch index: 939
# cuda:0
# Batch index: 940
# cuda:0
# Batch index: 941
# cuda:0
# Batch index: 942
# cuda:0
# Batch index: 943
# cuda:0
# Batch index: 944
# cuda:0
# Batch index: 945
# cuda:0
# Batch index: 946
# cuda:0
# Batch index: 947
# cuda:0
# Batch index: 948
# cuda:0
# Batch index: 949
# cuda:0
# Batch index: 950
# cuda:0
# Batch index: 951
# cuda:0
# Batch index: 952
# cuda:0
# Batch index: 953
# cuda:0
# Batch index: 954
# cuda:0
# Batch index: 955
# cuda:0
# Batch index: 956
# cuda:0
# Batch index: 957
# cuda:0
# Batch index: 958
# cuda:0
# Batch index: 959
# cuda:0
# Batch index: 960
# cuda:0
# Batch index: 961
# cuda:0
# Batch index: 962
# cuda:0
# Batch index: 963
# cuda:0
# Batch index: 964
# cuda:0
# Batch index: 965
# cuda:0
# Batch index: 966
# cuda:0
# Batch index: 967
# cuda:0
# Batch index: 968
# cuda:0
# Batch index: 969
# cuda:0
# Batch index: 970
# cuda:0
# Batch index: 971
# cuda:0
# Batch index: 972
# cuda:0
# Batch index: 973
# cuda:0
# Batch index: 974
# cuda:0
# Batch index: 975
# cuda:0
# Batch index: 976
# cuda:0
# Batch index: 977
# cuda:0
# Batch index: 978
# cuda:0
# Batch index: 979
# cuda:0
# Batch index: 980
# cuda:0
# Batch index: 981
# cuda:0
# Batch index: 982
# cuda:0
# Batch index: 983
# cuda:0
# Batch index: 984
# cuda:0
# Batch index: 985
# cuda:0
# Batch index: 986
# cuda:0
# Batch index: 987
# cuda:0
# Batch index: 988
# cuda:0
# Batch index: 989
# cuda:0
# Batch index: 990
# cuda:0
# Batch index: 991
# cuda:0
# Batch index: 992
# cuda:0
# Batch index: 993
# cuda:0
# Batch index: 994
# cuda:0
# Batch index: 995
# cuda:0
# Batch index: 996
# cuda:0
# Batch index: 997
# cuda:0
# Batch index: 998
# cuda:0
# Batch index: 999
# cuda:0
# Checkpoint guardado: checkpoint_fold1_latest.pth (Epoch 1, Batch 1000)
# Batch index: 1000
# cuda:0
# Batch index: 1001
# cuda:0
# Batch index: 1002
# cuda:0
# Batch index: 1003
# cuda:0
# Batch index: 1004
# cuda:0
# Batch index: 1005
# cuda:0
# Batch index: 1006
# cuda:0
# Batch index: 1007
# cuda:0
# Batch index: 1008
# cuda:0
# Batch index: 1009
# cuda:0
# Batch index: 1010
# cuda:0
# Batch index: 1011
# cuda:0
# Batch index: 1012
# cuda:0
# Batch index: 1013
# cuda:0
# Batch index: 1014
# cuda:0
# Batch index: 1015
# cuda:0
# Batch index: 1016
# cuda:0
# Batch index: 1017
# cuda:0
# Batch index: 1018
# cuda:0
# Batch index: 1019
# cuda:0
# Batch index: 1020
# cuda:0
# Batch index: 1021
# cuda:0
# Batch index: 1022
# cuda:0
# Batch index: 1023
# cuda:0
# Batch index: 1024
# cuda:0
# Batch index: 1025
# cuda:0
# Batch index: 1026
# cuda:0
# Batch index: 1027
# cuda:0
# Batch index: 1028
# cuda:0
# Batch index: 1029
# cuda:0
# Batch index: 1030
# cuda:0
# Batch index: 1031
# cuda:0
# Batch index: 1032
# cuda:0
# Batch index: 1033
# cuda:0
# Batch index: 1034
# cuda:0
# Batch index: 1035
# cuda:0
# Batch index: 1036
# cuda:0
# Batch index: 1037
# cuda:0
# Batch index: 1038
# cuda:0
# Batch index: 1039
# cuda:0
# Batch index: 1040
# cuda:0
# Batch index: 1041
# cuda:0
# Batch index: 1042
# cuda:0
# Batch index: 1043
# cuda:0
# Batch index: 1044
# cuda:0
# Batch index: 1045
# cuda:0
# Batch index: 1046
# cuda:0
# Batch index: 1047
# cuda:0
# Batch index: 1048
# cuda:0
# Batch index: 1049
# cuda:0
# Batch index: 1050
# cuda:0
# Batch index: 1051
# cuda:0
# Batch index: 1052
# cuda:0
# Batch index: 1053
# cuda:0
# Batch index: 1054
# cuda:0
# Batch index: 1055
# cuda:0
# Batch index: 1056
# cuda:0
# Batch index: 1057
# cuda:0
# Batch index: 1058
# cuda:0
# Batch index: 1059
# cuda:0
# Batch index: 1060
# cuda:0
# Batch index: 1061
# cuda:0
# Batch index: 1062
# cuda:0
# Batch index: 1063
# cuda:0
# Batch index: 1064
# cuda:0
# Batch index: 1065
# cuda:0
# Batch index: 1066
# cuda:0
# Batch index: 1067
# cuda:0
# Batch index: 1068
# cuda:0
# Batch index: 1069
# cuda:0
# Batch index: 1070
# cuda:0
# Batch index: 1071
# cuda:0
# Batch index: 1072
# cuda:0
# Batch index: 1073
# cuda:0
# Batch index: 1074
# cuda:0
# Batch index: 1075
# cuda:0
# Batch index: 1076
# cuda:0
# Batch index: 1077
# cuda:0
# Batch index: 1078
# cuda:0
# Batch index: 1079
# cuda:0
# Batch index: 1080
# cuda:0
# Batch index: 1081
# cuda:0
# Batch index: 1082
# cuda:0
# Batch index: 1083
# cuda:0
# Batch index: 1084
# cuda:0
# Batch index: 1085
# cuda:0
# Batch index: 1086
# cuda:0
# Batch index: 1087
# cuda:0
# Batch index: 1088
# cuda:0
# Batch index: 1089
# cuda:0
# Batch index: 1090
# cuda:0
# Batch index: 1091
# cuda:0
# Batch index: 1092
# cuda:0
# Batch index: 1093
# cuda:0
# Batch index: 1094
# cuda:0
# Batch index: 1095
# cuda:0
# Batch index: 1096
# cuda:0
# Batch index: 1097
# cuda:0
# Batch index: 1098
# cuda:0
# Batch index: 1099
# cuda:0
# Checkpoint guardado: checkpoint_fold1_latest.pth (Epoch 1, Batch 1100)
# Batch index: 1100
# cuda:0
# Batch index: 1101
# cuda:0
# Batch index: 1102
# cuda:0
# Batch index: 1103
# cuda:0
# Batch index: 1104
# cuda:0
# Batch index: 1105
# cuda:0
# Batch index: 1106
# cuda:0
# Batch index: 1107
# cuda:0
# Batch index: 1108
# cuda:0
# Batch index: 1109
# cuda:0
# Batch index: 1110
# cuda:0
# Batch index: 1111
# cuda:0
# Batch index: 1112
# cuda:0
# Batch index: 1113
# cuda:0
# Batch index: 1114
# cuda:0
# Batch index: 1115
# cuda:0
# Batch index: 1116
# cuda:0
# Batch index: 1117
# cuda:0
# Batch index: 1118
# cuda:0
# Batch index: 1119
# cuda:0
# Batch index: 1120
# cuda:0
# Batch index: 1121
# cuda:0
# Batch index: 1122
# cuda:0
# Batch index: 1123
# cuda:0
# Batch index: 1124
# cuda:0
# Batch index: 1125
# cuda:0
# Batch index: 1126
# cuda:0
# Batch index: 1127
# cuda:0
# Batch index: 1128
# cuda:0
# Batch index: 1129
# cuda:0
# Batch index: 1130
# cuda:0
# Batch index: 1131
# cuda:0
# Batch index: 1132
# cuda:0
# Batch index: 1133
# cuda:0
# Batch index: 1134
# cuda:0
# Batch index: 1135
# cuda:0
# Batch index: 1136
# cuda:0
# Batch index: 1137
# cuda:0
# Batch index: 1138
# cuda:0
# Batch index: 1139
# cuda:0
# Batch index: 1140
# cuda:0
# Batch index: 1141
# cuda:0
# Batch index: 1142
# cuda:0
# Batch index: 1143
# cuda:0
# Batch index: 1144
# cuda:0
# Batch index: 1145
# cuda:0
# Batch index: 1146
# cuda:0
# Batch index: 1147
# cuda:0
# Batch index: 1148
# cuda:0
# Batch index: 1149
# cuda:0
# Batch index: 1150
# cuda:0
# Batch index: 1151
# cuda:0
# Batch index: 1152
# cuda:0
# Batch index: 1153
# cuda:0
# Batch index: 1154
# cuda:0
# Batch index: 1155
# cuda:0
# Batch index: 1156
# cuda:0
# Batch index: 1157
# cuda:0
# Batch index: 1158
# cuda:0
# Batch index: 1159
# cuda:0
# Batch index: 1160
# cuda:0
# Batch index: 1161
# cuda:0
# Batch index: 1162
# cuda:0
# Batch index: 1163
# cuda:0
# Batch index: 1164
# cuda:0
# Batch index: 1165
# cuda:0
# Batch index: 1166
# cuda:0
# Batch index: 1167
# cuda:0
# Batch index: 1168
# cuda:0
# Batch index: 1169
# cuda:0
# Batch index: 1170
# cuda:0
# Batch index: 1171
# cuda:0
# Batch index: 1172
# cuda:0
# Batch index: 1173
# cuda:0
# Batch index: 1174
# cuda:0
# Batch index: 1175
# cuda:0
# Batch index: 1176
# cuda:0
# Batch index: 1177
# cuda:0
# Batch index: 1178
# cuda:0
# Batch index: 1179
# cuda:0
# Batch index: 1180
# cuda:0
# Batch index: 1181
# cuda:0
# Batch index: 1182
# cuda:0
# Batch index: 1183
# cuda:0
# Batch index: 1184
# cuda:0
# Batch index: 1185
# cuda:0
# Batch index: 1186
# cuda:0
# Batch index: 1187
# cuda:0
# Batch index: 1188
# cuda:0
# Batch index: 1189
# cuda:0
# Batch index: 1190
# cuda:0
# Batch index: 1191
# cuda:0
# Batch index: 1192
# cuda:0
# Batch index: 1193
# cuda:0
# Batch index: 1194
# cuda:0
# Batch index: 1195
# cuda:0
# Batch index: 1196
# cuda:0
# Batch index: 1197
# cuda:0
# Batch index: 1198
# cuda:0
# Batch index: 1199
# cuda:0
# Checkpoint guardado: checkpoint_fold1_latest.pth (Epoch 1, Batch 1200)
# Batch index: 1200
# cuda:0
# Batch index: 1201
# cuda:0
# Batch index: 1202
# cuda:0
# Batch index: 1203
# cuda:0
# Batch index: 1204
# cuda:0
# Batch index: 1205
# cuda:0
# Batch index: 1206
# cuda:0
# Batch index: 1207
# cuda:0
# Batch index: 1208
# cuda:0
# Batch index: 1209
# cuda:0
# Batch index: 1210
# cuda:0
# Batch index: 1211
# cuda:0
# Batch index: 1212
# cuda:0
# Batch index: 1213
# cuda:0
# Batch index: 1214
# cuda:0
# Batch index: 1215
# cuda:0
# Batch index: 1216
# cuda:0
# Batch index: 1217
# cuda:0
# Batch index: 1218
# cuda:0
# Batch index: 1219
# cuda:0
# Batch index: 1220
# cuda:0
# Batch index: 1221
# cuda:0
# Batch index: 1222
# cuda:0
# Batch index: 1223
# cuda:0
# Batch index: 1224
# cuda:0
# Batch index: 1225
# cuda:0
# Batch index: 1226
# cuda:0
# Batch index: 1227
# cuda:0
# Batch index: 1228
# cuda:0
# Batch index: 1229
# cuda:0
# Batch index: 1230
# cuda:0
# Batch index: 1231
# cuda:0
# Batch index: 1232
# cuda:0
# Batch index: 1233
# cuda:0
# Batch index: 1234
# cuda:0
# Batch index: 1235
# cuda:0
# Batch index: 1236
# cuda:0
# Batch index: 1237
# cuda:0
# Batch index: 1238
# cuda:0
# Batch index: 1239
# cuda:0
# Batch index: 1240
# cuda:0
# Batch index: 1241
# cuda:0
# Batch index: 1242
# cuda:0
# Batch index: 1243
# cuda:0
# Batch index: 1244
# cuda:0
# Batch index: 1245
# cuda:0
# Batch index: 1246
# cuda:0
# Batch index: 1247
# cuda:0
# Batch index: 1248
# cuda:0
# Batch index: 1249
# cuda:0
# Batch index: 1250
# cuda:0
# Batch index: 1251
# cuda:0
# Batch index: 1252
# cuda:0
# Batch index: 1253
# cuda:0
# Batch index: 1254
# cuda:0
# Batch index: 1255
# cuda:0
# Batch index: 1256
# cuda:0
# Batch index: 1257
# cuda:0
# Batch index: 1258
# cuda:0
# Batch index: 1259
# cuda:0
# Batch index: 1260
# cuda:0
# Batch index: 1261
# cuda:0
# Batch index: 1262
# cuda:0
# Batch index: 1263
# cuda:0
# Batch index: 1264
# cuda:0
# Batch index: 1265
# cuda:0
# Batch index: 1266
# cuda:0
# Batch index: 1267
# cuda:0
# Batch index: 1268
# cuda:0
# Batch index: 1269
# cuda:0
# Batch index: 1270
# cuda:0
# Batch index: 1271
# cuda:0
# Batch index: 1272
# cuda:0
# Batch index: 1273
# cuda:0
# Batch index: 1274
# cuda:0
# Batch index: 1275
# cuda:0
# Batch index: 1276
# cuda:0
# Batch index: 1277
# cuda:0
# Batch index: 1278
# cuda:0
# Batch index: 1279
# cuda:0
# Batch index: 1280
# cuda:0
# Batch index: 1281
# cuda:0
# Batch index: 1282
# cuda:0
# Batch index: 1283
# cuda:0
# Batch index: 1284
# cuda:0
# Batch index: 1285
# cuda:0
# Batch index: 1286
# cuda:0
# Batch index: 1287
# cuda:0
# Batch index: 1288
# cuda:0
# Batch index: 1289
# cuda:0
# Batch index: 1290
# cuda:0
# Batch index: 1291
# cuda:0
# Batch index: 1292
# cuda:0
# Batch index: 1293
# cuda:0
# Batch index: 1294
# cuda:0
# Batch index: 1295
# cuda:0
# Batch index: 1296
# cuda:0
# Batch index: 1297
# cuda:0
# Batch index: 1298
# cuda:0
# Batch index: 1299
# cuda:0
# Checkpoint guardado: checkpoint_fold1_latest.pth (Epoch 1, Batch 1300)
# Batch index: 1300
# cuda:0
# Batch index: 1301
# cuda:0
# Batch index: 1302
# cuda:0
# Batch index: 1303
# cuda:0
# Batch index: 1304
# cuda:0
# Batch index: 1305
# cuda:0
# Batch index: 1306
# cuda:0
# Batch index: 1307
# cuda:0
# Batch index: 1308
# cuda:0
# Batch index: 1309
# cuda:0
# Batch index: 1310
# cuda:0
# Batch index: 1311
# cuda:0
# Batch index: 1312
# cuda:0
# Batch index: 1313
# cuda:0
# Batch index: 1314
# cuda:0
# Batch index: 1315
# cuda:0
# Batch index: 1316
# cuda:0
# Batch index: 1317
# cuda:0
# Batch index: 1318
# cuda:0
# Batch index: 1319
# cuda:0
# Batch index: 1320
# cuda:0
# Batch index: 1321
# cuda:0
# Batch index: 1322
# cuda:0
# Batch index: 1323
# cuda:0
# Batch index: 1324
# cuda:0
# Batch index: 1325
# cuda:0
# Batch index: 1326
# cuda:0
# Batch index: 1327
# cuda:0
# Batch index: 1328
# cuda:0
# Batch index: 1329
# cuda:0
# Batch index: 1330
# cuda:0
# Batch index: 1331
# cuda:0
# Batch index: 1332
# cuda:0
# Batch index: 1333
# cuda:0
# Batch index: 1334
# cuda:0
# Batch index: 1335
# cuda:0
# Batch index: 1336
# cuda:0
# Batch index: 1337
# cuda:0
# Batch index: 1338
# cuda:0
# Batch index: 1339
# cuda:0
# Batch index: 1340
# cuda:0
# Batch index: 1341
# cuda:0
# Batch index: 1342
# cuda:0
# Batch index: 1343
# cuda:0
# Batch index: 1344
# cuda:0
# Batch index: 1345
# cuda:0
# Batch index: 1346
# cuda:0
# Batch index: 1347
# cuda:0
# Batch index: 1348
# cuda:0
# Batch index: 1349
# cuda:0
# Batch index: 1350
# cuda:0
# Batch index: 1351
# cuda:0
# Batch index: 1352
# cuda:0
# Batch index: 1353
# cuda:0
# Batch index: 1354
# cuda:0
# Batch index: 1355
# cuda:0
# Batch index: 1356
# cuda:0
# Batch index: 1357
# cuda:0
# Batch index: 1358
# cuda:0
# Batch index: 1359
# cuda:0
# Batch index: 1360
# cuda:0
# Batch index: 1361
# cuda:0
# Batch index: 1362
# cuda:0
# Batch index: 1363
# cuda:0
# Batch index: 1364
# cuda:0
# Batch index: 1365
# cuda:0
# Batch index: 1366
# cuda:0
# Batch index: 1367
# cuda:0
# Batch index: 1368
# cuda:0
# Batch index: 1369
# cuda:0
# Batch index: 1370
# cuda:0
# Batch index: 1371
# cuda:0
# Batch index: 1372
# cuda:0
# Batch index: 1373
# cuda:0
# Batch index: 1374
# cuda:0
# Batch index: 1375
# cuda:0
# Batch index: 1376
# cuda:0
# Batch index: 1377
# cuda:0
# Batch index: 1378
# cuda:0
# Batch index: 1379
# cuda:0
# Batch index: 1380
# cuda:0
# Batch index: 1381
# cuda:0
# Batch index: 1382
# cuda:0
# Batch index: 1383
# cuda:0
# Batch index: 1384
# cuda:0
# Batch index: 1385
# cuda:0
# Batch index: 1386
# cuda:0
# Batch index: 1387
# cuda:0
# Batch index: 1388
# cuda:0
# Batch index: 1389
# cuda:0
# Batch index: 1390
# cuda:0
# Batch index: 1391
# cuda:0
# Batch index: 1392
# cuda:0
# Batch index: 1393
# cuda:0
# Batch index: 1394
# cuda:0
# Batch index: 1395
# cuda:0
# Batch index: 1396
# cuda:0
# Batch index: 1397
# cuda:0
# Batch index: 1398
# cuda:0
# Batch index: 1399
# cuda:0
# Checkpoint guardado: checkpoint_fold1_latest.pth (Epoch 1, Batch 1400)
# Batch index: 1400
# cuda:0
# Batch index: 1401
# cuda:0
# Batch index: 1402
# cuda:0
# Batch index: 1403
# cuda:0
# Batch index: 1404
# cuda:0
# Batch index: 1405
# cuda:0
# Batch index: 1406
# cuda:0
# Batch index: 1407
# cuda:0
# Batch index: 1408
# cuda:0
# Batch index: 1409
# cuda:0
# Batch index: 1410
# cuda:0
# Batch index: 1411
# cuda:0
# Batch index: 1412
# cuda:0
# Batch index: 1413
# cuda:0
# Batch index: 1414
# cuda:0
# Batch index: 1415
# cuda:0
# Batch index: 1416
# cuda:0
# Batch index: 1417
# cuda:0
# Batch index: 1418
# cuda:0
# Batch index: 1419
# cuda:0
# Batch index: 1420
# cuda:0
# Batch index: 1421
# cuda:0
# Batch index: 1422
# cuda:0
# Batch index: 1423
# cuda:0
# Batch index: 1424
# cuda:0
# Batch index: 1425
# cuda:0
# Batch index: 1426
# cuda:0
# Batch index: 1427
# cuda:0
# Batch index: 1428
# cuda:0
# Batch index: 1429
# cuda:0
# Batch index: 1430
# cuda:0
# Batch index: 1431
# cuda:0
# Batch index: 1432
# cuda:0
# Batch index: 1433
# cuda:0
# Batch index: 1434
# cuda:0
# Batch index: 1435
# cuda:0
# Batch index: 1436
# cuda:0
# Batch index: 1437
# cuda:0
# Batch index: 1438
# cuda:0
# Batch index: 1439
# cuda:0
# Batch index: 1440
# cuda:0
# Batch index: 1441
# cuda:0
# Batch index: 1442
# cuda:0
# Batch index: 1443
# cuda:0
# Batch index: 1444
# cuda:0
# Batch index: 1445
# cuda:0
# Batch index: 1446
# cuda:0
# Batch index: 1447
# cuda:0
# Batch index: 1448
# cuda:0
# Batch index: 1449
# cuda:0
# Batch index: 1450
# cuda:0
# Batch index: 1451
# cuda:0
# Batch index: 1452
# cuda:0
# Batch index: 1453
# cuda:0
# Batch index: 1454
# cuda:0
# Batch index: 1455
# cuda:0
# Batch index: 1456
# cuda:0
# Batch index: 1457
# cuda:0
# Batch index: 1458
# cuda:0
# Batch index: 1459
# cuda:0
# Batch index: 1460
# cuda:0
# Batch index: 1461
# cuda:0
# Batch index: 1462
# cuda:0
# Batch index: 1463
# cuda:0
# Batch index: 1464
# cuda:0
# Batch index: 1465
# cuda:0
# Batch index: 1466
# cuda:0
# Batch index: 1467
# cuda:0
# Batch index: 1468
# cuda:0
# Batch index: 1469
# cuda:0
# Batch index: 1470
# cuda:0
# Batch index: 1471
# cuda:0
# Batch index: 1472
# cuda:0
# Batch index: 1473
# cuda:0
# Batch index: 1474
# cuda:0
# Batch index: 1475
# cuda:0
# Batch index: 1476
# cuda:0
# Batch index: 1477
# cuda:0
# Batch index: 1478
# cuda:0
# Batch index: 1479
# cuda:0
# Batch index: 1480
# cuda:0
# Batch index: 1481
# cuda:0
# Batch index: 1482
# cuda:0
# Batch index: 1483
# cuda:0
# Batch index: 1484
# cuda:0
# Batch index: 1485
# cuda:0
# Batch index: 1486
# cuda:0
# Batch index: 1487
# cuda:0
# Batch index: 1488
# cuda:0
# Batch index: 1489
# cuda:0
# Batch index: 1490
# cuda:0
# Batch index: 1491
# cuda:0
# Batch index: 1492
# cuda:0
# Batch index: 1493
# cuda:0
# Batch index: 1494
# cuda:0
# Batch index: 1495
# cuda:0
# Batch index: 1496
# cuda:0
# Batch index: 1497
# cuda:0
# Batch index: 1498
# cuda:0
# Batch index: 1499
# cuda:0
# Checkpoint guardado: checkpoint_fold1_latest.pth (Epoch 1, Batch 1500)
# Batch index: 1500
# cuda:0
# Batch index: 1501
# cuda:0
# Batch index: 1502
# cuda:0
# Batch index: 1503
# cuda:0
# Batch index: 1504
# cuda:0
# Batch index: 1505
# cuda:0
# Batch index: 1506
# cuda:0
# Batch index: 1507
# cuda:0
# Batch index: 1508
# cuda:0
# Batch index: 1509
# cuda:0
# Batch index: 1510
# cuda:0
# Batch index: 1511
# cuda:0
# Batch index: 1512
# cuda:0
# Batch index: 1513
# cuda:0
# Batch index: 1514
# cuda:0
# Batch index: 1515
# cuda:0
# Batch index: 1516
# cuda:0
# Batch index: 1517
# cuda:0
# Batch index: 1518
# cuda:0
# Batch index: 1519
# cuda:0
# Batch index: 1520
# cuda:0
# Batch index: 1521
# cuda:0
# Batch index: 1522
# cuda:0
# Batch index: 1523
# cuda:0
# Batch index: 1524
# cuda:0
# Batch index: 1525
# cuda:0
# Batch index: 1526
# cuda:0
# Batch index: 1527
# cuda:0
# Batch index: 1528
# cuda:0
# Batch index: 1529
# cuda:0
# Batch index: 1530
# cuda:0
# Batch index: 1531
# cuda:0
# Batch index: 1532
# cuda:0
# Batch index: 1533
# cuda:0
# Batch index: 1534
# cuda:0
# Batch index: 1535
# cuda:0
# Batch index: 1536
# cuda:0
# Batch index: 1537
# cuda:0
# Batch index: 1538
# cuda:0
# Batch index: 1539
# cuda:0
# Batch index: 1540
# cuda:0
# Batch index: 1541
# cuda:0
# Batch index: 1542
# cuda:0
# Batch index: 1543
# cuda:0
# Batch index: 1544
# cuda:0
# Batch index: 1545
# cuda:0
# Batch index: 1546
# cuda:0
# Batch index: 1547
# cuda:0
# Batch index: 1548
# cuda:0
# Batch index: 1549
# cuda:0
# Batch index: 1550
# cuda:0
# Batch index: 1551
# cuda:0
# Batch index: 1552
# cuda:0
# Batch index: 1553
# cuda:0
# Batch index: 1554
# cuda:0
# Batch index: 1555
# cuda:0
# Batch index: 1556
# cuda:0
# Batch index: 1557
# cuda:0
# Batch index: 1558
# cuda:0
# Batch index: 1559
# cuda:0
# Batch index: 1560
# cuda:0
# Batch index: 1561
# cuda:0
# Batch index: 1562
# cuda:0
# Batch index: 1563
# cuda:0
# Batch index: 1564
# cuda:0
# Batch index: 1565
# cuda:0
# Batch index: 1566
# cuda:0
# Batch index: 1567
# cuda:0
# Batch index: 1568
# cuda:0
# Batch index: 1569
# cuda:0
# Batch index: 1570
# cuda:0
# Batch index: 1571
# cuda:0
# Batch index: 1572
# cuda:0
# Batch index: 1573
# cuda:0
# Batch index: 1574
# cuda:0
# Batch index: 1575
# cuda:0
# Batch index: 1576
# cuda:0
# Batch index: 1577
# cuda:0
# Batch index: 1578
# cuda:0
# Batch index: 1579
# cuda:0
# Batch index: 1580
# cuda:0
# Batch index: 1581
# cuda:0
# Batch index: 1582
# cuda:0
# Batch index: 1583
# cuda:0
# Batch index: 1584
# cuda:0
# Batch index: 1585
# cuda:0
# Batch index: 1586
# cuda:0
# Batch index: 1587
# cuda:0
# Batch index: 1588
# cuda:0
# Batch index: 1589
# cuda:0
# Batch index: 1590
# cuda:0
# Batch index: 1591
# cuda:0
# Batch index: 1592
# cuda:0
# Batch index: 1593
# cuda:0
# Batch index: 1594
# cuda:0
# Batch index: 1595
# cuda:0
# Batch index: 1596
# cuda:0
# Batch index: 1597
# cuda:0
# Batch index: 1598
# cuda:0
# Batch index: 1599
# cuda:0
# Checkpoint guardado: checkpoint_fold1_latest.pth (Epoch 1, Batch 1600)
# Batch index: 1600
# cuda:0
# Batch index: 1601
# cuda:0
# Batch index: 1602
# cuda:0
# Batch index: 1603
# cuda:0
# Batch index: 1604
# cuda:0
# Batch index: 1605
# cuda:0
# Batch index: 1606
# cuda:0
# Batch index: 1607
# cuda:0
# Batch index: 1608
# cuda:0
# Batch index: 1609
# cuda:0
# Batch index: 1610
# cuda:0
# Batch index: 1611
# cuda:0
# Batch index: 1612
# cuda:0
# Batch index: 1613
# cuda:0
# Batch index: 1614
# cuda:0
# Batch index: 1615
# cuda:0
# Batch index: 1616
# cuda:0
# Batch index: 1617
# cuda:0
# Batch index: 1618
# cuda:0
# Batch index: 1619
# cuda:0
# Batch index: 1620
# cuda:0
# Batch index: 1621
# cuda:0
# Batch index: 1622
# cuda:0
# Batch index: 1623
# cuda:0
# Batch index: 1624
# cuda:0
# Batch index: 1625
# cuda:0
# Batch index: 1626
# cuda:0
# Batch index: 1627
# cuda:0
# Batch index: 1628
# cuda:0
# Batch index: 1629
# cuda:0
# Batch index: 1630
# cuda:0
# Batch index: 1631
# cuda:0
# Batch index: 1632
# cuda:0
# Batch index: 1633
# cuda:0
# Batch index: 1634
# cuda:0
# Batch index: 1635
# cuda:0
# Batch index: 1636
# cuda:0
# Batch index: 1637
# cuda:0
# Batch index: 1638
# cuda:0
# Batch index: 1639
# cuda:0
# Batch index: 1640
# cuda:0
# Batch index: 1641
# cuda:0
# Batch index: 1642
# cuda:0
# Batch index: 1643
# cuda:0
# Batch index: 1644
# cuda:0
# Batch index: 1645
# cuda:0
# Batch index: 1646
# cuda:0
# Batch index: 1647
# cuda:0
# Batch index: 1648
# cuda:0
# Batch index: 1649
# cuda:0
# Batch index: 1650
# cuda:0
# Batch index: 1651
# cuda:0
# Batch index: 1652
# cuda:0
# Batch index: 1653
# cuda:0
# Batch index: 1654
# cuda:0
# Batch index: 1655
# cuda:0
# Batch index: 1656
# cuda:0
# Batch index: 1657
# cuda:0
# Batch index: 1658
# cuda:0
# Batch index: 1659
# cuda:0
# Batch index: 1660
# cuda:0
# Batch index: 1661
# cuda:0
# Batch index: 1662
# cuda:0
# Batch index: 1663
# cuda:0
# Batch index: 1664
# cuda:0
# Batch index: 1665
# cuda:0
# Batch index: 1666
# cuda:0
# Batch index: 1667
# cuda:0
# Batch index: 1668
# cuda:0
# Batch index: 1669
# cuda:0
# Batch index: 1670
# cuda:0
# Batch index: 1671
# cuda:0
# Batch index: 1672
# cuda:0
# Batch index: 1673
# cuda:0
# Batch index: 1674
# cuda:0
# Batch index: 1675
# cuda:0
# Batch index: 1676
# cuda:0
# Batch index: 1677
# cuda:0
# Batch index: 1678
# cuda:0
# Batch index: 1679
# cuda:0
# Batch index: 1680
# cuda:0
# Batch index: 1681
# cuda:0
# Batch index: 1682
# cuda:0
# Batch index: 1683
# cuda:0
# Batch index: 1684
# cuda:0
# Batch index: 1685
# cuda:0
# Batch index: 1686
# cuda:0
# Batch index: 1687
# cuda:0
# Batch index: 1688
# cuda:0
# Batch index: 1689
# cuda:0
# Batch index: 1690
# cuda:0
# Batch index: 1691
# cuda:0
# Batch index: 1692
# cuda:0
# Batch index: 1693
# cuda:0
# Batch index: 1694
# cuda:0
# Batch index: 1695
# cuda:0
# Batch index: 1696
# cuda:0
# Batch index: 1697
# cuda:0
# Batch index: 1698
# cuda:0
# Batch index: 1699
# cuda:0
# Checkpoint guardado: checkpoint_fold1_latest.pth (Epoch 1, Batch 1700)
# Batch index: 1700
# cuda:0
# Batch index: 1701
# cuda:0
# Batch index: 1702
# cuda:0
# Batch index: 1703
# cuda:0
# Batch index: 1704
# cuda:0
# Batch index: 1705
# cuda:0
# Batch index: 1706
# cuda:0
# Batch index: 1707
# cuda:0
# Batch index: 1708
# cuda:0
# Batch index: 1709
# cuda:0
# Batch index: 1710
# cuda:0
# Batch index: 1711
# cuda:0
# Batch index: 1712
# cuda:0
# Batch index: 1713
# cuda:0
# Batch index: 1714
# cuda:0
# Batch index: 1715
# cuda:0
# Batch index: 1716
# cuda:0
# Batch index: 1717
# cuda:0
# Batch index: 1718
# cuda:0
# Batch index: 1719
# cuda:0
# Batch index: 1720
# cuda:0
# Batch index: 1721
# cuda:0
# Batch index: 1722
# cuda:0
# Batch index: 1723
# cuda:0
# Batch index: 1724
# cuda:0
# Batch index: 1725
# cuda:0
# Batch index: 1726
# cuda:0
# Batch index: 1727
# cuda:0
# Batch index: 1728
# cuda:0
# Batch index: 1729
# cuda:0
# Batch index: 1730
# cuda:0
# Batch index: 1731
# cuda:0
# Batch index: 1732
# cuda:0
# Batch index: 1733
# cuda:0
# Batch index: 1734
# cuda:0
# Batch index: 1735
# cuda:0
# Batch index: 1736
# cuda:0
# Batch index: 1737
# cuda:0
# Batch index: 1738
# cuda:0
# Batch index: 1739
# cuda:0
# Batch index: 1740
# cuda:0
# Batch index: 1741
# cuda:0
# Batch index: 1742
# cuda:0
# Batch index: 1743
# cuda:0
# Batch index: 1744
# cuda:0
# Batch index: 1745
# cuda:0
# Batch index: 1746
# cuda:0
# Batch index: 1747
# cuda:0
# Batch index: 1748
# cuda:0
# Batch index: 1749
# cuda:0
# Batch index: 1750
# cuda:0
# Batch index: 1751
# cuda:0
# Batch index: 1752
# cuda:0
# Batch index: 1753
# cuda:0
# Batch index: 1754
# cuda:0
# Batch index: 1755
# cuda:0
# Batch index: 1756
# cuda:0
# Batch index: 1757
# cuda:0
# Batch index: 1758
# cuda:0
# Batch index: 1759
# cuda:0
# Batch index: 1760
# cuda:0
# Batch index: 1761
# cuda:0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 71
#      68 loss.backward()
#      69 optimizer.step()
# ---> 71 running_loss += loss.item()
#      72 _, predicted = outputs.max(1)
#      73 total += labels.size(0)
#
# KeyboardInterrupt:
